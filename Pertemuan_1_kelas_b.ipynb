# %% [markdown]
# <a href="https://colab.research.google.com/github/mhvvn/Arduino-Sensor/blob/main/Pertemuan_1_kelas_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 5

c = a+b
print ("hasilnya : ",c)
# Out:
# hasilnya :  15

# %% [markdown]
# Program di atas ada operasi matematika sederhana

# %%
# Biodata Saya

nama = "Veven"
umur = 28
jurusan = "Elektro"
prodi = "TRPE"
matakuliah = "Pemrograman Dasar"
status_lulus = True

#printah untuk menampilkan nilai pada variable


print(nama)
print (umur)
print (jurusan)
print (prodi)
print(matakuliah)
print(status_lulus)
# Out:
# Veven
# 28
# Elektro
# TRPE
# Pemrograman Dasar
# True
